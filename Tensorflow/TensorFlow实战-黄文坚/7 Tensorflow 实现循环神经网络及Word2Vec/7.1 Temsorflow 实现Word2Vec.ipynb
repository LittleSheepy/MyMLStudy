# %%
import collections
import math
import os
import random
import zipfile
import numpy as np
import urllib
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

words = read_data(filename)
print('Data size', len(words))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %% [markdown]
# 我们使用collections.Counter来统计单词频数，然后用most_common获取前50000个

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.


graph = tf.Graph()
with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-6-63f504cc218c>:53: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in range(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = "Nearest to %s:" % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  294.1356506347656
# Nearest to on: ricans, username, infighting, holyoke, conferring, stink, fun, schematics,
# Nearest to nine: held, morgue, katharina, count, esso, schumpeter, rated, hendrix,
# Nearest to d: ietf, koichi, fanciful, achievable, burgesses, sib, yearning, refuges,
# Nearest to or: lapis, xii, medley, presbyter, khalil, tei, ithilien, faring,
# Nearest to from: laurens, gunner, principled, squaw, eazy, kyo, ly, aids,
# Nearest to his: aegis, terra, loved, lomo, basin, stepson, far, kal,
# Nearest to world: trois, siege, marksmanship, bosman, sz, recluse, abroad, arrow,
# Nearest to also: apocalyptic, palestinians, sheen, aba, malignancies, influencing, sudetenland, rebuke,
# Nearest to has: nodes, human, wwf, serum, trisomy, ipcc, circumvent, norwegian,
# Nearest to such: bitmap, affinity, asin, devoured, uruguayan, gls, betting, apples,
# Nearest to their: clinging, basie, natalia, koufax, stenella, syndicalism, berle, golfo,
# Nearest to who: kasner, gibbons, chalker, halas, fountain, dystopia, bd, trebizond,
# Nearest to which: cta, degeneracy, colonia, polyethylene, thermotropic, brevity, numidia, velar,
# Nearest to many: sbc, scissors, building, web, burglary, kore, nationwide, posited,
# Nearest to UNK: ionian, panth, consummated, actinidia, bhumi, ceres, hawaiian, brooks,
# Nearest to new: hissarlik, stijl, noel, esq, tonnage, lafcadio, insurers, godf,
# Average loss at step  2000 :  113.71141426372527
# Average loss at step  4000 :  52.59822251677513
# Average loss at step  6000 :  33.58101142668724
# Average loss at step  8000 :  23.453975101351737
# Average loss at step  10000 :  18.296733419656753
# Nearest to on: in, and, of, fun, proposition, tubing, roper, by,
# Nearest to nine: reginae, zero, victoriae, phi, seven, gland, six, eight,
# Nearest to d: mathbf, inhibition, benzodiazepines, saito, fanciful, oxidation, preservation, ietf,
# Nearest to or: and, UNK, michael, private, attracted, chancellor, bride, legislatures,
# Nearest to from: in, of, for, meridian, few, decorative, by, aids,
# Nearest to his: the, aegis, their, ad, terra, historians, gilbert, hillside,
# Nearest to world: edmonton, male, siege, reginae, abroad, trois, fiercely, naive,
# Nearest to also: sheen, malignancies, mathbf, and, it, minorities, UNK, purchase,
# Nearest to has: is, serum, into, seen, had, human, gland, nodes,
# Nearest to such: affinity, bitmap, uruguayan, seater, food, roper, dies, introduce,
# Nearest to their: breaking, person, his, the, require, amo, closely, unnecessary,
# Nearest to who: abwehr, compulsion, similarly, vs, dick, municipalities, municipal, not,
# Nearest to which: this, ibook, essendon, that, and, psi, constant, then,
# Nearest to many: reginae, the, web, ibook, building, define, rotate, found,
# Nearest to UNK: reginae, and, one, the, cat, six, mathbf, vs,
# Nearest to new: tubing, six, tackles, representing, for, ng, flags, one,
# Average loss at step  12000 :  13.91680249094963
# Average loss at step  14000 :  11.493165007352829
# Average loss at step  16000 :  9.871456907629966
# Average loss at step  18000 :  8.724289772033691
# Average loss at step  20000 :  7.7401332217454915
# Nearest to on: in, aquila, and, of, by, from, for, two,
# Nearest to nine: eight, seven, zero, six, five, four, dasyprocta, agouti,
# Nearest to d: b, and, dmt, pseudonyms, inhibition, captures, koichi, in,
# Nearest to or: and, three, five, for, aquila, zero, two, seven,
# Nearest to from: in, and, by, of, into, for, five, nine,
# Nearest to his: the, their, aegis, reginae, riding, penalty, gilbert, asbestos,
# Nearest to world: siege, male, edmonton, reginae, trois, fiercely, abadan, abroad,
# Nearest to also: it, apocalyptic, and, which, sheen, often, operatorname, rolled,
# Nearest to has: is, had, was, into, serum, and, hbox, faced,
# Nearest to such: affinity, bitmap, roper, introduce, seater, dies, food, uruguayan,
# Nearest to their: his, the, its, breaking, require, person, amo, offences,
# Nearest to who: not, dick, which, that, dystopia, compulsion, municipal, two,
# Nearest to which: that, this, and, aquila, ibook, also, then, aoc,
# Nearest to many: reginae, dasyprocta, ibook, the, define, found, part, web,
# Nearest to UNK: reginae, hbox, dasyprocta, aquila, and, agouti, six, victoriae,
# Nearest to new: tubing, for, representing, tackles, amino, UNK, six, spin,
# Average loss at step  22000 :  7.322365929365158
# Average loss at step  24000 :  7.044008307099342
# Average loss at step  26000 :  6.704591893911362
# Average loss at step  28000 :  6.169707437038421
# Average loss at step  30000 :  6.098952792465687
# Nearest to on: in, two, and, from, of, aquila, for, by,
# Nearest to nine: eight, seven, six, five, four, zero, three, dasyprocta,
# Nearest to d: b, akh, inhibition, captures, pseudonyms, dmt, benzodiazepines, sharply,
# Nearest to or: and, abet, aquila, for, eight, UNK, primigenius, four,
# Nearest to from: in, into, and, by, of, for, on, five,
# Nearest to his: their, the, amalthea, its, s, aegis, her, gilbert,
# Nearest to world: siege, compressibility, trois, edmonton, male, fiercely, reginae, abadan,
# Nearest to also: aba, often, it, which, still, apocalyptic, sheen, peripheral,
# Nearest to has: had, is, was, have, serum, into, stems, wwf,
# Nearest to such: well, affinity, bitmap, arbitral, dies, seater, drone, roper,
# Nearest to their: the, his, its, primigenius, breaking, var, this, offences,
# Nearest to who: which, not, there, and, abiotic, he, dystopia, that,
# Nearest to which: that, this, and, also, aquila, psi, abet, one,
# Nearest to many: some, reginae, ibook, found, dasyprocta, part, define, aphids,
# Nearest to UNK: reginae, primigenius, dasyprocta, hbox, agouti, aquila, abet, absalom,
# Nearest to new: hissarlik, tubing, esq, ifvs, xe, tonnage, representing, for,
# Average loss at step  32000 :  5.8641023209095
# Average loss at step  34000 :  5.932628086090088
# Average loss at step  36000 :  5.6785842498540875
# Average loss at step  38000 :  5.230957875132561
# Average loss at step  40000 :  5.449666777610779
# Nearest to on: in, aquila, from, since, for, bryozoans, abet, agouti,
# Nearest to nine: eight, seven, six, zero, five, four, dasyprocta, three,
# Nearest to d: b, UNK, inhibition, akh, captures, benzodiazepines, koichi, pseudonyms,
# Nearest to or: and, four, abet, three, aquila, eight, amalthea, six,
# Nearest to from: in, into, and, of, by, on, for, dasyprocta,
# Nearest to his: their, the, its, amalthea, her, s, primigenius, reginae,
# Nearest to world: trois, siege, male, compressibility, fiercely, abadan, edmonton, naive,
# Nearest to also: aba, often, which, it, still, now, peripheral, generally,
# Nearest to has: had, is, was, have, stems, serum, vma, asylum,
# Nearest to such: well, affinity, arbitral, dies, bitmap, drone, seem, seater,
# Nearest to their: his, its, the, adamantium, primigenius, breaking, var, proportions,
# Nearest to who: which, he, there, dystopia, abiotic, not, that, they,
# Nearest to which: that, this, and, it, also, one, aquila, abet,
# Nearest to many: some, reginae, the, these, several, dasyprocta, found, ibook,
# Nearest to UNK: reginae, primigenius, hbox, dasyprocta, aquila, agouti, absalom, abet,
# Nearest to new: tubing, hissarlik, esq, ifvs, xe, expired, spin, representing,
# Average loss at step  42000 :  5.3213548098802566
# Average loss at step  44000 :  5.361686803102494
# Average loss at step  46000 :  5.275280789256096
# Average loss at step  48000 :  5.031436980843544
# Average loss at step  50000 :  5.177458577275276
# Nearest to on: in, aquila, from, thibetanus, two, since, at, into,
# Nearest to nine: eight, seven, six, zero, four, five, three, dasyprocta,
# Nearest to d: b, inhibition, benzodiazepines, koichi, captures, bj, akh, neighbour,
# Nearest to or: and, abet, aquila, eight, amalthea, three, seven, nguni,
# Nearest to from: into, in, and, for, by, on, nine, through,
# Nearest to his: their, the, its, her, amalthea, s, primigenius, abet,
# Nearest to world: trois, siege, male, compressibility, naive, first, wardrobe, judaizers,
# Nearest to also: aba, which, often, still, it, now, then, generally,
# Nearest to has: had, was, is, have, stems, vma, asylum, prism,
# Nearest to such: well, affinity, arbitral, dies, drone, shura, seater, seem,
# Nearest to their: his, its, the, adamantium, proportions, primigenius, var, breaking,
# Nearest to who: which, he, there, dystopia, abiotic, not, they, concorde,
# Nearest to which: that, this, also, and, it, who, aquila, but,
# Nearest to many: some, these, several, reginae, the, dasyprocta, thibetanus, implementing,
# Nearest to UNK: reginae, primigenius, dasyprocta, hbox, thibetanus, nguni, aquila, four,
# Nearest to new: roshan, tubing, hissarlik, esq, expired, ifvs, xe, representing,
# Average loss at step  52000 :  5.176928654670715
# Average loss at step  54000 :  5.106248836994171
# Average loss at step  56000 :  5.080107118010521
# Average loss at step  58000 :  5.121210174798965
# Average loss at step  60000 :  4.946980528116226
# Nearest to on: in, ssbn, callithrix, from, aquila, tamarin, thibetanus, within,
# Nearest to nine: eight, six, seven, five, four, zero, three, callithrix,
# Nearest to d: b, cebus, inhibition, leontopithecus, benzodiazepines, koichi, five, six,
# Nearest to or: and, callithrix, tamarin, amalthea, abet, aquila, michelob, cebus,
# Nearest to from: into, in, and, on, through, nine, microcebus, between,
# Nearest to his: their, its, her, the, amalthea, s, cebus, callithrix,
# Nearest to world: siege, trois, male, compressibility, encrypt, sz, naive, wardrobe,
# Nearest to also: aba, often, which, still, now, cebus, it, ssbn,
# Nearest to has: had, was, is, have, stems, asylum, callithrix, vma,
# Nearest to such: well, affinity, are, arbitral, known, shura, dies, taos,
# Nearest to their: its, his, the, callithrix, ssbn, her, adamantium, tamarin,
# Nearest to who: which, he, they, there, abiotic, dystopia, concorde, that,
# Nearest to which: that, this, it, also, who, tamarin, ssbn, microcebus,
# Nearest to many: some, several, these, reginae, other, cebus, leontopithecus, any,
# Nearest to UNK: microcebus, cebus, reginae, tamarin, hbox, primigenius, dasyprocta, callithrix,
# Nearest to new: hissarlik, roshan, tubing, castiglione, tamarin, expired, xe, esq,
# Average loss at step  62000 :  4.7999182467460635
# Average loss at step  64000 :  4.776411052107811
# Average loss at step  66000 :  4.9760979547500614
# Average loss at step  68000 :  4.92769966673851
# Average loss at step  70000 :  4.767324063420296
# Nearest to on: in, ssbn, callithrix, within, aquila, upon, from, tamarin,
# Nearest to nine: eight, six, seven, five, four, zero, three, callithrix,
# Nearest to d: b, cebus, inhibition, benzodiazepines, UNK, leontopithecus, koichi, bj,
# Nearest to or: and, callithrix, amalthea, tamarin, aquila, but, michelob, nguni,
# Nearest to from: into, in, through, and, between, on, microcebus, nine,
# Nearest to his: their, its, her, the, amalthea, s, cebus, callithrix,
# Nearest to world: siege, trois, male, compressibility, wardrobe, sz, encrypt, first,
# Nearest to also: often, aba, which, still, now, generally, cebus, it,
# Nearest to has: had, was, is, have, stems, attorneys, callithrix, prism,
# Nearest to such: well, affinity, are, known, these, some, many, arbitral,
# Nearest to their: its, his, the, callithrix, her, some, ssbn, adamantium,
# Nearest to who: he, which, they, there, abiotic, dystopia, concorde, that,
# Nearest to which: that, this, also, it, and, but, what, tamarin,
# Nearest to many: some, several, these, other, reginae, cebus, leontopithecus, all,
# Nearest to UNK: microcebus, reginae, thaler, cebus, tamarin, dasyprocta, thibetanus, ssbn,
# Nearest to new: roshan, hissarlik, tubing, castiglione, tamarin, expired, xe, mitral,
# Average loss at step  72000 :  4.80184473824501
# Average loss at step  74000 :  4.781457615435124
# Average loss at step  76000 :  4.861601726412773
# Average loss at step  78000 :  4.797321698546409
# Average loss at step  80000 :  4.813863909602166
# Nearest to on: in, ssbn, callithrix, upon, at, aquila, within, from,
# Nearest to nine: eight, seven, six, five, four, zero, three, callithrix,
# Nearest to d: b, cebus, benzodiazepines, bj, koichi, four, inhibition, h,
# Nearest to or: and, callithrix, amalthea, tamarin, than, aquila, michelob, nguni,
# Nearest to from: into, through, in, and, between, by, microcebus, since,
# Nearest to his: their, its, her, the, amalthea, s, your, cebus,
# Nearest to world: trois, judaizers, siege, male, encrypt, compressibility, wardrobe, sz,
# Nearest to also: often, aba, still, which, now, it, cebus, generally,
# Nearest to has: had, have, was, is, attorneys, stems, trisomy, asylum,
# Nearest to such: well, these, known, many, some, including, are, affinity,
# Nearest to their: its, his, the, her, callithrix, ssbn, tamarin, adamantium,
# Nearest to who: he, they, which, there, dystopia, abiotic, concorde, also,
# Nearest to which: that, this, also, it, tamarin, but, what, ssbn,
# Nearest to many: some, several, these, other, all, reginae, leontopithecus, cebus,
# Nearest to UNK: microcebus, reginae, cebus, tamarin, hbox, thaler, michelob, mitral,
# Nearest to new: roshan, hissarlik, tubing, tamarin, xe, castiglione, expired, mitral,
# Average loss at step  82000 :  4.8168952981233595
# Average loss at step  84000 :  4.795882321953774
# Average loss at step  86000 :  4.745982576489449
# Average loss at step  88000 :  4.695469887495041
# Average loss at step  90000 :  4.768278278946877
# Nearest to on: in, upon, ssbn, callithrix, aquila, within, thaler, at,
# Nearest to nine: eight, seven, six, five, four, zero, callithrix, cebus,
# Nearest to d: b, six, cebus, four, h, moorcock, benzodiazepines, koichi,
# Nearest to or: and, callithrix, michelob, but, amalthea, tamarin, aquila, than,
# Nearest to from: into, through, in, and, between, of, at, microcebus,
# Nearest to his: their, her, its, the, amalthea, s, your, cebus,
# Nearest to world: judaizers, trois, siege, encrypt, wardrobe, compressibility, male, naive,
# Nearest to also: often, aba, still, which, now, usually, cebus, sometimes,
# Nearest to has: had, have, is, was, attorneys, having, stems, callithrix,
# Nearest to such: well, these, some, known, many, including, are, ajaccio,
# Nearest to their: its, his, the, her, callithrix, ssbn, some, tamarin,
# Nearest to who: he, they, abiotic, dystopia, which, she, there, lawgiver,
# Nearest to which: that, this, but, also, it, what, tamarin, aquila,
# Nearest to many: some, several, these, other, all, cebus, reginae, leontopithecus,
# Nearest to UNK: microcebus, cebus, reginae, dasyprocta, tamarin, thaler, hbox, mitral,
# Nearest to new: roshan, tubing, tamarin, hissarlik, expired, xe, mitral, one,
# Average loss at step  92000 :  4.699923400640488
# Average loss at step  94000 :  4.6276091803312305
# Average loss at step  96000 :  4.731355243444443
# Average loss at step  98000 :  4.619060059428215
# Average loss at step  100000 :  4.682179039478302
# Nearest to on: in, upon, ssbn, callithrix, at, within, during, under,
# Nearest to nine: eight, seven, six, five, four, zero, callithrix, three,
# Nearest to d: b, cebus, leontopithecus, five, h, six, moorcock, org,
# Nearest to or: and, callithrix, but, aquila, michelob, amalthea, tamarin, than,
# Nearest to from: into, in, through, at, and, since, on, before,
# Nearest to his: their, her, its, the, your, s, amalthea, my,
# Nearest to world: judaizers, trois, siege, male, encrypt, odense, wardrobe, compressibility,
# Nearest to also: often, still, aba, now, which, usually, generally, sometimes,
# Nearest to has: had, have, was, is, attorneys, weightings, stems, callithrix,
# Nearest to such: well, these, known, many, some, including, are, ajaccio,
# Nearest to their: its, his, the, her, callithrix, some, ssbn, your,
# Nearest to who: he, they, dystopia, she, abiotic, which, there, never,
# Nearest to which: that, this, but, also, it, what, and, ssbn,
# Nearest to many: some, several, these, endothermic, all, other, reginae, cebus,
# Nearest to UNK: microcebus, reginae, cebus, tamarin, microsite, primigenius, hbox, dasyprocta,
# Nearest to new: roshan, hissarlik, tubing, expired, tamarin, xe, representing, esq,

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

  #%%
try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 200
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
