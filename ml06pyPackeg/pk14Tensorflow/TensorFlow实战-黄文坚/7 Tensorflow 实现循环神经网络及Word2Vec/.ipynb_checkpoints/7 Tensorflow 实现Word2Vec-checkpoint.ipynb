# %%
import collections
import math
import os
import random
import zipfile

import numpy as np
import urllib
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

# %%
words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
words
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'whilst',
#  'the',
#  'term',
#  'is',
#  'still',
#  'used',
#  'in',
#  'a',
#  'pejorative',
#  'way',
#  'to',
#  'describe',
#  'any',
#  'act',
#  'that',
#  'used',
#  'violent',
#  'means',
#  'to',
#  'destroy',
#  'the',
#  'organization',
#  'of',
#  'society',
#  'it',
#  'has',
#  'also',
#  'been',
#  'taken',
#  'up',
#  'as',
#  'a',
#  'positive',
#  'label',
#  'by',
#  'self',
#  'defined',
#  'anarchists',
#  'the',
#  'word',
#  'anarchism',
#  'is',
#  'derived',
#  'from',
#  'the',
#  'greek',
#  'without',
#  'archons',
#  'ruler',
#  'chief',
#  'king',
#  'anarchism',
#  'as',
#  'a',
#  'political',
#  'philosophy',
#  'is',
#  'the',
#  'belief',
#  'that',
#  'rulers',
#  'are',
#  'unnecessary',
#  'and',
#  'should',
#  'be',
#  'abolished',
#  'although',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'what',
#  'this',
#  'means',
#  'anarchism',
#  'also',
#  'refers',
#  'to',
#  'related',
#  'social',
#  'movements',
#  'that',
#  'advocate',
#  'the',
#  'elimination',
#  'of',
#  'authoritarian',
#  'institutions',
#  'particularly',
#  'the',
#  'state',
#  'the',
#  'word',
#  'anarchy',
#  'as',
#  'most',
#  'anarchists',
#  'use',
#  'it',
#  'does',
#  'not',
#  'imply',
#  'chaos',
#  'nihilism',
#  'or',
#  'anomie',
#  'but',
#  'rather',
#  'a',
#  'harmonious',
#  'anti',
#  'authoritarian',
#  'society',
#  'in',
#  'place',
#  'of',
#  'what',
#  'are',
#  'regarded',
#  'as',
#  'authoritarian',
#  'political',
#  'structures',
#  'and',
#  'coercive',
#  'economic',
#  'institutions',
#  'anarchists',
#  'advocate',
#  'social',
#  'relations',
#  'based',
#  'upon',
#  'voluntary',
#  'association',
#  'of',
#  'autonomous',
#  'individuals',
#  'mutual',
#  'aid',
#  'and',
#  'self',
#  'governance',
#  'while',
#  'anarchism',
#  'is',
#  'most',
#  'easily',
#  'defined',
#  'by',
#  'what',
#  'it',
#  'is',
#  'against',
#  'anarchists',
#  'also',
#  'offer',
#  'positive',
#  'visions',
#  'of',
#  'what',
#  'they',
#  'believe',
#  'to',
#  'be',
#  'a',
#  'truly',
#  'free',
#  'society',
#  'however',
#  'ideas',
#  'about',
#  'how',
#  'an',
#  'anarchist',
#  'society',
#  'might',
#  'work',
#  'vary',
#  'considerably',
#  'especially',
#  'with',
#  'respect',
#  'to',
#  'economics',
#  'there',
#  'is',
#  'also',
#  'disagreement',
#  'about',
#  'how',
#  'a',
#  'free',
#  'society',
#  'might',
#  'be',
#  'brought',
#  'about',
#  'origins',
#  'and',
#  'predecessors',
#  'kropotkin',
#  'and',
#  'others',
#  'argue',
#  'that',
#  'before',
#  'recorded',
#  'history',
#  'human',
#  'society',
#  'was',
#  'organized',
#  'on',
#  'anarchist',
#  'principles',
#  'most',
#  'anthropologists',
#  'follow',
#  'kropotkin',
#  'and',
#  'engels',
#  'in',
#  'believing',
#  'that',
#  'hunter',
#  'gatherer',
#  'bands',
#  'were',
#  'egalitarian',
#  'and',
#  'lacked',
#  'division',
#  'of',
#  'labour',
#  'accumulated',
#  'wealth',
#  'or',
#  'decreed',
#  'law',
#  'and',
#  'had',
#  'equal',
#  'access',
#  'to',
#  'resources',
#  'william',
#  'godwin',
#  'anarchists',
#  'including',
#  'the',
#  'the',
#  'anarchy',
#  'organisation',
#  'and',
#  'rothbard',
#  'find',
#  'anarchist',
#  'attitudes',
#  'in',
#  'taoism',
#  'from',
#  'ancient',
#  'china',
#  'kropotkin',
#  'found',
#  'similar',
#  'ideas',
#  'in',
#  'stoic',
#  'zeno',
#  'of',
#  'citium',
#  'according',
#  'to',
#  'kropotkin',
#  'zeno',
#  'repudiated',
#  'the',
#  'omnipotence',
#  'of',
#  'the',
#  'state',
#  'its',
#  'intervention',
#  'and',
#  'regimentation',
#  'and',
#  'proclaimed',
#  'the',
#  'sovereignty',
#  'of',
#  'the',
#  'moral',
#  'law',
#  'of',
#  'the',
#  'individual',
#  'the',
#  'anabaptists',
#  'of',
#  'one',
#  'six',
#  'th',
#  'century',
#  'europe',
#  'are',
#  'sometimes',
#  'considered',
#  'to',
#  'be',
#  'religious',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'bertrand',
#  'russell',
#  'in',
#  'his',
#  'history',
#  'of',
#  'western',
#  'philosophy',
#  'writes',
#  'that',
#  'the',
#  'anabaptists',
#  'repudiated',
#  'all',
#  'law',
#  'since',
#  'they',
#  'held',
#  'that',
#  'the',
#  'good',
#  'man',
#  'will',
#  'be',
#  'guided',
#  'at',
#  'every',
#  'moment',
#  'by',
#  'the',
#  'holy',
#  'spirit',
#  'from',
#  'this',
#  'premise',
#  'they',
#  'arrive',
#  'at',
#  'communism',
#  'the',
#  'diggers',
#  'or',
#  'true',
#  'levellers',
#  'were',
#  'an',
#  'early',
#  'communistic',
#  'movement',
#  'during',
#  'the',
#  'time',
#  'of',
#  'the',
#  'english',
#  'civil',
#  'war',
#  'and',
#  'are',
#  'considered',
#  'by',
#  'some',
#  'as',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'in',
#  'the',
#  'modern',
#  'era',
#  'the',
#  'first',
#  'to',
#  'use',
#  'the',
#  'term',
#  'to',
#  'mean',
#  'something',
#  'other',
#  'than',
#  'chaos',
#  'was',
#  'louis',
#  'armand',
#  'baron',
#  'de',
#  'lahontan',
#  'in',
#  'his',
#  'nouveaux',
#  'voyages',
#  'dans',
#  'l',
#  'am',
#  'rique',
#  'septentrionale',
#  'one',
#  'seven',
#  'zero',
#  'three',
#  'where',
#  'he',
#  'described',
#  'the',
#  'indigenous',
#  'american',
#  'society',
#  'which',
#  'had',
#  'no',
#  'state',
#  'laws',
#  'prisons',
#  'priests',
#  'or',
#  'private',
#  'property',
#  'as',
#  'being',
#  'in',
#  'anarchy',
#  'russell',
#  'means',
#  'a',
#  'libertarian',
#  'and',
#  'leader',
#  'in',
#  'the',
#  'american',
#  'indian',
#  'movement',
#  'has',
#  'repeatedly',
#  'stated',
#  'that',
#  'he',
#  'is',
#  'an',
#  'anarchist',
#  'and',
#  'so',
#  'are',
#  'all',
#  'his',
#  'ancestors',
#  'in',
#  'one',
#  'seven',
#  'nine',
#  'three',
#  'in',
#  'the',
#  'thick',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'william',
#  'godwin',
#  'published',
#  'an',
#  'enquiry',
#  'concerning',
#  'political',
#  'justice',
#  'although',
#  'godwin',
#  'did',
#  'not',
#  'use',
#  'the',
#  'word',
#  'anarchism',
#  'many',
#  'later',
#  'anarchists',
#  'have',
#  'regarded',
#  'this',
#  'book',
#  'as',
#  'the',
#  'first',
#  'major',
#  'anarchist',
#  'text',
#  'and',
#  'godwin',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'philosophical',
#  'anarchism',
#  'but',
#  'at',
#  'this',
#  'point',
#  'no',
#  'anarchist',
#  'movement',
#  'yet',
#  'existed',
#  'and',
#  'the',
#  'term',
#  'anarchiste',
#  'was',
#  'known',
#  'mainly',
#  'as',
#  'an',
#  'insult',
#  'hurled',
#  'by',
#  'the',
#  'bourgeois',
#  'girondins',
#  'at',
#  'more',
#  'radical',
#  'elements',
#  'in',
#  'the',
#  'french',
#  'revolution',
#  'the',
#  'first',
#  'self',
#  'labelled',
#  'anarchist',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'it',
#  'is',
#  'commonly',
#  'held',
#  'that',
#  'it',
#  'wasn',
#  't',
#  'until',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'published',
#  'what',
#  'is',
#  'property',
#  'in',
#  'one',
#  'eight',
#  'four',
#  'zero',
#  'that',
#  'the',
#  'term',
#  'anarchist',
#  'was',
#  'adopted',
#  'as',
#  'a',
#  'self',
#  'description',
#  'it',
#  'is',
#  'for',
#  'this',
#  'reason',
#  'that',
#  'some',
#  'claim',
#  'proudhon',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'modern',
#  'anarchist',
#  'theory',
#  'in',
#  'what',
#  'is',
#  'property',
#  'proudhon',
#  'answers',
#  'with',
#  'the',
#  'famous',
#  'accusation',
#  'property',
#  'is',
#  'theft',
#  'in',
#  'this',
#  'work',
#  'he',
#  'opposed',
#  'the',
#  'institution',
#  'of',
#  'decreed',
#  'property',
#  'propri',
#  't',
#  'where',
#  'owners',
#  'have',
#  'complete',
#  'rights',
#  'to',
#  'use',
#  'and',
#  'abuse',
#  'their',
#  'property',
#  'as',
#  'they',
#  'wish',
#  'such',
#  'as',
#  'exploiting',
#  'workers',
#  'for',
#  'profit',
#  'in',
#  'its',
#  'place',
#  'proudhon',
#  'supported',
#  'what',
#  'he',
#  'called',
#  'possession',
#  'individuals',
#  'can',
#  'have',
#  'limited',
#  'rights',
#  'to',
#  'use',
#  'resources',
#  'capital',
#  'and',
#  'goods',
#  'in',
#  'accordance',
#  'with',
#  'principles',
#  'of',
#  'equality',
#  'and',
#  'justice',
#  'proudhon',
#  's',
#  'vision',
#  'of',
#  'anarchy',
#  'which',
#  'he',
#  'called',
#  'mutualism',
#  'mutuellisme',
#  'involved',
#  'an',
#  'exchange',
#  'economy',
#  'where',
#  'individuals',
#  'and',
#  'groups',
#  'could',
#  'trade',
#  'the',
#  'products',
#  'of',
#  'their',
#  'labor',
#  'using',
#  'labor',
#  'notes',
#  'which',
#  'represented',
#  'the',
#  'amount',
#  'of',
#  'working',
#  'time',
#  'involved',
#  'in',
#  'production',
#  'this',
#  'would',
#  'ensure',
#  'that',
#  'no',
#  'one',
#  'would',
#  'profit',
#  'from',
#  'the',
#  'labor',
#  'of',
#  'others',
#  'workers',
#  'could',
#  'freely',
#  'join',
#  'together',
#  'in',
#  'co',
#  'operative',
#  'workshops',
#  'an',
#  'interest',
#  'free',
#  'bank',
#  'would',
#  'be',
#  'set',
#  'up',
#  'to',
#  'provide',
#  'everyone',
#  'with',
#  'access',
#  'to',
#  'the',
#  'means',
#  'of',
#  'production',
#  'proudhon',
#  's',
#  'ideas',
#  'were',
#  'influential',
#  'within',
#  'french',
#  'working',
#  'class',
#  'movements',
#  'and',
#  'his',
#  'followers',
#  'were',
#  'active',
#  'in',
#  'the',
#  'revolution',
#  'of',
#  'one',
#  'eight',
#  'four',
#  'eight',
#  'in',
#  'france',
#  'proudhon',
#  's',
#  'philosophy',
#  'of',
#  'property',
#  'is',
#  'complex',
#  'it',
#  'was',
#  'developed',
#  'in',
#  'a',
#  'number',
#  'of',
#  'works',
#  'over',
#  'his',
#  'lifetime',
#  'and',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'some',
#  'of',
#  'his',
#  'ideas',
#  'for',
#  'more',
#  'detailed',
#  'discussion',
#  'see',
#  'here',
#  'max',
#  'stirner',
#  's',
#  'egoism',
#  'in',
#  'his',
#  'the',
#  'ego',
#  'and',
#  'its',
#  'own',
#  'stirner',
#  'argued',
#  'that',
#  'most',
#  'commonly',
#  'accepted',
#  'social',
#  'institutions',
#  'including',
#  'the',
#  'notion',
#  'of',
#  'state',
#  'property',
#  'as',
#  'a',
#  'right',
#  'natural',
#  'rights',
#  'in',
#  'general',
#  'and',
#  'the',
#  'very',
#  'notion',
#  'of',
#  'society',
#  'were',
#  'mere',
#  'illusions',
#  'or',
#  'ghosts',
#  'in',
#  'the',
#  'mind',
#  'saying',
#  'of',
#  'society',
#  'that',
#  'the',
#  'individuals',
#  'are',
#  'its',
#  'reality',
#  'he',
#  'advocated',
#  'egoism',
#  'and',
#  'a',
#  'form',
#  'of',
#  'amoralism',
#  'in',
#  'which',
#  'individuals',
#  'would',
#  'unite',
#  'in',
#  'associations',
#  'of',
#  'egoists',
#  'only',
#  'when',
#  'it',
#  'was',
#  'in',
#  'their',
#  'self',
#  'interest',
#  'to',
#  'do',
#  'so',
#  'for',
#  'him',
#  'property',
#  'simply',
#  'comes',
#  'about',
#  'through',
#  'might',
#  'whoever',
#  'knows',
#  'how',
#  'to',
#  'take',
#  'to',
#  'defend',
#  'the',
#  'thing',
#  'to',
#  'him',
#  'belongs',
#  'property',
#  'and',
#  'what',
#  'i',
#  'have',
#  'in',
#  'my',
#  'power',
#  'that',
#  'is',
#  'my',
#  'own',
#  'so',
#  'long',
#  'as',
#  'i',
#  'assert',
#  'myself',
#  'as',
#  'holder',
#  'i',
#  'am',
#  'the',
#  'proprietor',
#  'of',
#  'the',
#  'thing',
#  'stirner',
#  'never',
#  'called',
#  'himself',
#  'an',
#  'anarchist',
#  'he',
#  'accepted',
#  'only',
#  'the',
#  'label',
#  'egoist',
#  'nevertheless',
#  'his',
#  'ideas',
#  'were',
#  'influential',
#  'on',
#  'many',
#  'individualistically',
#  'inclined',
#  'anarchists',
#  'although',
#  'interpretations',
#  'of',
#  'his',
#  'thought',
#  'are',
#  'diverse',
#  ...]

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

# %% [markdown]
# 我们使用collections.Counter来统计单词频数，然后用most_common获取前50000个

# %%
def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-907714f24455> in <module>()
# ----> 1 data, count, dictionary, reverse_dictionary = build_dataset(words)
#       2 del words  # Hint to reduce memory.
#       3 print('Most common words (+UNK)', count[:5])
#       4 print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
#       5
#
# NameError: name 'words' is not defined

# %%
batch_size = 8
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# %%
batch = np.ndarray(shape=(batch_size), dtype=np.int32)
labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
batch,labels
# Out:
# (array([  45088767,          0, -349693456,       2046,          2,
#                  0,         -1,         -1]), array([[1701580756],
#         [1769238607],
#         [   7564911],
#         [         0],
#         [         0],
#         [         0],
#         [        15],
#         [         0]]))

# %%
span = 2 * skip_window + 1 # [ skip_window target skip_window ]
buffer = collections.deque(maxlen=span)
span, buffer
# Out:
# (3, deque([]))

# %%
for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)

# %%
buffer
# Out:
# deque([345, 1819, 20])

# %%
data_index
# Out:
# 113

# %%
batch_size // num_skips,batch_size,num_skips
# Out:
# (4, 8, 2)

# %%
print(batch,labels)
for i in range(batch_size // num_skips):
    print("i =",i)
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
        print("j=",j)
        print("targets_to_avoid", targets_to_avoid)
        while target in targets_to_avoid:
            target = random.randint(0, span - 1)
            print("target=", target)
        targets_to_avoid.append(target)
        print("targets_to_avoid", targets_to_avoid)
        batch[i * num_skips + j] = buffer[skip_window]
        labels[i * num_skips + j, 0] = buffer[target]
        print("==",buffer[skip_window], buffer[target])
        print(i * num_skips + j,batch,labels)
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    print("\n")
# Out:
# [ 363  363 5234 5234   37   37 1138 1138] [[5234]
#  [  33]
#  [ 363]
#  [  37]
#  [1138]
#  [5234]
#  [   7]
#  [  37]]
# i = 0
# j= 0
# targets_to_avoid [1]
# target= 1
# target= 1
# targets_to_avoid [1, 2]
# == 1819 20
# 0 [1819  363 5234 5234   37   37 1138 1138] [[  20]
#  [  33]
#  [ 363]
#  [  37]
#  [1138]
#  [5234]
#  [   7]
#  [  37]]
# j= 1
# targets_to_avoid [1, 2]
# target= 2
# target= 2
# targets_to_avoid [1, 2, 0]
# == 1819 345
# 1 [1819 1819 5234 5234   37   37 1138 1138] [[  20]
#  [ 345]
#  [ 363]
#  [  37]
#  [1138]
#  [5234]
#  [   7]
#  [  37]]
#
#
# i = 1
# j= 0
# targets_to_avoid [1]
# target= 1
# target= 1
# target= 1
# targets_to_avoid [1, 2]
# == 20 4861
# 2 [1819 1819   20 5234   37   37 1138 1138] [[  20]
#  [ 345]
#  [4861]
#  [  37]
#  [1138]
#  [5234]
#  [   7]
#  [  37]]
# j= 1
# targets_to_avoid [1, 2]
# target= 2
# target= 1
# targets_to_avoid [1, 2, 0]
# == 20 1819
# 3 [1819 1819   20   20   37   37 1138 1138] [[  20]
#  [ 345]
#  [4861]
#  [1819]
#  [1138]
#  [5234]
#  [   7]
#  [  37]]
#
#
# i = 2
# j= 0
# targets_to_avoid [1]
# target= 1
# target= 1
# targets_to_avoid [1, 0]
# == 4861 20
# 4 [1819 1819   20   20 4861   37 1138 1138] [[  20]
#  [ 345]
#  [4861]
#  [1819]
#  [  20]
#  [5234]
#  [   7]
#  [  37]]
# j= 1
# targets_to_avoid [1, 0]
# target= 0
# targets_to_avoid [1, 0, 2]
# == 4861 1
# 5 [1819 1819   20   20 4861 4861 1138 1138] [[  20]
#  [ 345]
#  [4861]
#  [1819]
#  [  20]
#  [   1]
#  [   7]
#  [  37]]
#
#
# i = 3
# j= 0
# targets_to_avoid [1]
# target= 1
# targets_to_avoid [1, 2]
# == 1 6754
# 6 [1819 1819   20   20 4861 4861    1 1138] [[  20]
#  [ 345]
#  [4861]
#  [1819]
#  [  20]
#  [   1]
#  [6754]
#  [  37]]
# j= 1
# targets_to_avoid [1, 2]
# target= 2
# target= 1
# target= 1
# target= 1
# target= 2
# target= 2
# targets_to_avoid [1, 2, 0]
# == 1 4861
# 7 [1819 1819   20   20 4861 4861    1    1] [[  20]
#  [ 345]
#  [4861]
#  [1819]
#  [  20]
#  [   1]
#  [6754]
#  [4861]]

# %%
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 249 without -> 321 greek
# 249 without -> 44612 archons
# 44612 archons -> 2878 ruler
# 44612 archons -> 249 without
# 2878 ruler -> 44612 archons
# 2878 ruler -> 793 chief
# 793 chief -> 2878 ruler
# 793 chief -> 187 king

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
      '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 2 of -> 1 the
# 2 of -> 0 UNK
# 1 the -> 2 of
# 1 the -> 151 french
# 151 french -> 855 revolution
# 151 french -> 1 the
# 855 revolution -> 3581 whilst
# 855 revolution -> 151 french

# %%
batch
# Out:
# array([ 59,  59, 156, 156, 128, 128, 742, 742])

# %%
labels
# Out:
# array([[ 46],
#        [156],
#        [ 59],
#        [128],
#        [742],
#        [156],
#        [128],
#        [477]])

# %%
# Step 4: Build and train a skip-gram model.
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

# %%
graph = tf.Graph()
with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-20-28f91f1bb429>:37: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print("Initialized")

  average_loss = 0
  for step in range(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print("Average loss at step ", step, ": ", average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log_str = "Nearest to %s:" % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = "%s %s," % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  269.4713134765625
# Nearest to zero: subjugated, larousse, relate, archive, surgeon, masuria, toledo, mulder,
# Nearest to up: ranked, arabah, timeless, remaking, words, williams, dmitry, resettlement,
# Nearest to people: balzac, reject, destruct, carbonic, cuff, mug, preeminence, mesa,
# Nearest to and: graceland, reich, maximize, offset, grind, removed, combustion, cartoonist,
# Nearest to however: croats, blood, electron, caverns, contrasting, geri, cocker, disgraced,
# Nearest to into: griffey, pidgin, noted, river, legation, embalmed, dirty, uneventful,
# Nearest to united: flue, jeopardy, centralizing, americas, cripps, veteran, oxycoccus, bun,
# Nearest to would: sec, drown, caching, analyse, endings, intellectuals, poet, quickly,
# Nearest to has: undergraduates, restrain, tartarus, liberated, sayed, ethnocentrism, tanganyika, draught,
# Nearest to five: visionaries, paleocene, aasen, waley, litani, finalised, allied, commas,
# Nearest to th: stoned, hier, qm, smack, boosting, cider, hau, tiergarten,
# Nearest to while: brotherly, culver, meanwhile, sabbath, iliad, proteus, ticketing, end,
# Nearest to be: plateau, depp, moving, fonts, shrinking, somewhat, overt, computer,
# Nearest to during: erika, outermost, ssbn, stomach, stylised, analyte, modena, staggered,
# Nearest to after: beets, misinformation, penises, anthropos, malabar, millay, fleet, desylva,
# Nearest to when: emissary, macy, tyr, magisterial, parable, mardi, lurker, nomenclature,
# Average loss at step  2000 :  114.19182879829407
# Average loss at step  4000 :  52.31410534596443
# Average loss at step  6000 :  33.36664949381351
# Average loss at step  8000 :  23.515008761644363
# Average loss at step  10000 :  17.844219475984573
# Nearest to zero: nine, vs, victoriae, eight, five, austin, six, cl,
# Nearest to up: ranked, words, afghani, modes, williams, real, opera, altenberg,
# Nearest to people: gland, reject, bracelet, eichmann, carbonic, countries, sold, cracking,
# Nearest to and: of, in, or, for, UNK, to, one, vs,
# Nearest to however: quadrilateral, blood, analogue, became, electron, dynasty, photosynthetic, decline,
# Nearest to into: dirty, cl, nine, river, extradition, reprinted, noted, consonants,
# Nearest to united: gland, vs, americas, phi, prep, treaty, court, changing,
# Nearest to would: can, and, sec, atom, poet, intellectuals, map, should,
# Nearest to has: is, cl, vs, dagny, var, prototype, was, combat,
# Nearest to five: zero, cl, vs, six, nine, austin, agave, three,
# Nearest to th: vs, six, nearly, phi, seven, fao, finding, phoenix,
# Nearest to while: brotherly, end, tissue, optional, dog, meanwhile, ready, iliad,
# Nearest to be: according, bckgr, stuck, plateau, overt, as, educational, pierre,
# Nearest to during: two, victoriae, in, items, outermost, stomach, agave, tracks,
# Nearest to after: impulse, aeneas, for, intent, gains, gland, brando, fleet,
# Nearest to when: var, large, analogue, vs, gland, mathbf, protons, inc,
# Average loss at step  12000 :  13.857520778298378
# Average loss at step  14000 :  11.770415491104126
# Average loss at step  16000 :  10.01349157257378
# Average loss at step  18000 :  8.75776060128212
# Average loss at step  20000 :  7.8186863490343095
# Nearest to zero: five, eight, nine, dasyprocta, six, seven, four, three,
# Nearest to up: ranked, modes, afghani, shifting, estimation, dasyprocta, words, prosecutor,
# Nearest to people: gland, reject, bracelet, iota, carbonic, eichmann, lindsay, crops,
# Nearest to and: in, or, of, dasyprocta, for, birkenau, one, agouti,
# Nearest to however: croats, quadrilateral, analogue, blood, became, and, johanna, continuity,
# Nearest to into: by, agouti, at, extradition, in, and, dirty, regained,
# Nearest to united: gland, vs, americas, gul, absalom, prep, phi, dasyprocta,
# Nearest to would: can, sec, should, to, atom, intellectuals, poet, and,
# Nearest to has: is, was, had, have, cl, by, prototype, vs,
# Nearest to five: zero, nine, dasyprocta, six, eight, two, three, four,
# Nearest to th: six, vs, nearly, phi, nine, seven, zero, temples,
# Nearest to while: brotherly, of, optional, end, agouti, dog, which, meanwhile,
# Nearest to be: have, according, was, as, astoria, bckgr, are, fonts,
# Nearest to during: in, of, agouti, two, and, outermost, stomach, victoriae,
# Nearest to after: for, from, anthropos, aeneas, intent, impulse, following, of,
# Nearest to when: in, var, huguenot, large, subkey, with, truetype, analogue,
# Average loss at step  22000 :  7.064850900948048
# Average loss at step  24000 :  6.990378719806671
# Average loss at step  26000 :  6.655317247509957
# Average loss at step  28000 :  6.218177815556526
# Average loss at step  30000 :  6.228424065232277
# Nearest to zero: eight, five, six, dasyprocta, nine, seven, four, three,
# Nearest to up: modes, ranked, shifting, afghani, estimation, prosecutor, dasyprocta, real,
# Nearest to people: gland, reject, akita, iota, carbonic, balzac, bracelet, crops,
# Nearest to and: or, dasyprocta, in, of, agouti, amalthea, for, but,
# Nearest to however: quadrilateral, croats, analogue, became, but, johanna, and, blood,
# Nearest to into: by, in, at, and, agouti, from, with, extradition,
# Nearest to united: gland, vs, americas, gul, agp, of, prep, absalom,
# Nearest to would: can, should, to, sec, atom, and, will, akkad,
# Nearest to has: is, was, had, have, cl, waldemar, by, prototype,
# Nearest to five: six, four, eight, seven, three, nine, zero, two,
# Nearest to th: six, seven, sponsors, vs, nine, eight, zero, nearly,
# Nearest to while: claris, agouti, optional, of, end, brotherly, UNK, and,
# Nearest to be: have, are, according, almighty, was, amalthea, is, as,
# Nearest to during: in, agouti, of, and, from, three, through, agave,
# Nearest to after: for, from, in, following, and, aeneas, intent, by,
# Nearest to when: in, and, huguenot, through, var, at, was, over,
# Average loss at step  32000 :  5.855429369926453
# Average loss at step  34000 :  5.860655863165856
# Average loss at step  36000 :  5.739854576587677
# Average loss at step  38000 :  5.272014201402664
# Average loss at step  40000 :  5.499684950828552
# Nearest to zero: five, eight, six, seven, dasyprocta, nine, four, three,
# Nearest to up: modes, ranked, shifting, afghani, dasyprocta, estimation, prosecutor, altenberg,
# Nearest to people: aveiro, gland, reject, iota, carbonic, akita, lindsay, hcl,
# Nearest to and: or, dasyprocta, agouti, but, seven, in, amalthea, six,
# Nearest to however: but, and, quadrilateral, croats, analogue, johanna, became, continuity,
# Nearest to into: by, from, and, at, agouti, in, regained, dirty,
# Nearest to united: gland, vs, americas, gul, agp, absalom, prep, screenwriters,
# Nearest to would: can, should, sec, to, will, may, intellectuals, could,
# Nearest to has: is, was, had, have, waldemar, cl, akita, never,
# Nearest to five: six, four, seven, three, eight, zero, two, nine,
# Nearest to th: six, eight, seven, sponsors, vs, nearly, phi, cider,
# Nearest to while: aveiro, and, agouti, until, UNK, claris, end, after,
# Nearest to be: have, are, been, according, was, almighty, by, is,
# Nearest to during: in, from, agouti, at, through, agave, for, and,
# Nearest to after: for, from, following, when, in, before, intent, aeneas,
# Nearest to when: in, and, after, through, over, at, but, for,
# Average loss at step  42000 :  5.34892343223095
# Average loss at step  44000 :  5.32878590130806
# Average loss at step  46000 :  5.280883137822151
# Average loss at step  48000 :  5.018624229311943
# Average loss at step  50000 :  5.186743597626686
# Nearest to zero: seven, eight, six, five, nine, dasyprocta, four, three,
# Nearest to up: modes, shifting, them, altenberg, dasyprocta, real, anacondas, afghani,
# Nearest to people: aveiro, gland, reject, carbonic, akita, iota, crops, bracelet,
# Nearest to and: or, dasyprocta, thibetanus, but, agouti, in, hbox, seven,
# Nearest to however: but, quadrilateral, analogue, johanna, and, thibetanus, continuity, became,
# Nearest to into: from, by, agouti, at, in, with, extradition, through,
# Nearest to united: tabula, gland, vs, americas, gul, agp, screenwriters, prep,
# Nearest to would: can, should, will, could, sec, may, to, must,
# Nearest to has: had, was, is, have, cl, waldemar, solicitation, akita,
# Nearest to five: six, four, three, eight, seven, zero, nine, dasyprocta,
# Nearest to th: six, seven, eight, thibetanus, nine, sponsors, vs, one,
# Nearest to while: aveiro, and, agouti, until, after, dasyprocta, eight, four,
# Nearest to be: have, been, was, are, almighty, were, according, thibetanus,
# Nearest to during: in, from, at, and, through, agouti, when, agave,
# Nearest to after: when, before, following, for, from, by, gland, impulse,
# Nearest to when: after, but, if, although, through, four, before, and,
# Average loss at step  52000 :  5.166466032624244
# Average loss at step  54000 :  5.134449111223221
# Average loss at step  56000 :  5.0569470208883285
# Average loss at step  58000 :  5.151302039861679
# Average loss at step  60000 :  4.957539879918098
# Nearest to zero: five, eight, six, seven, four, nine, dasyprocta, three,
# Nearest to up: them, him, modes, shifting, anacondas, hungary, nonzero, microcebus,
# Nearest to people: aveiro, gland, reject, carbonic, callithrix, iota, akita, sartre,
# Nearest to and: or, thibetanus, dasyprocta, tamarin, callithrix, but, microcebus, agouti,
# Nearest to however: but, johanna, quadrilateral, analogue, bebox, that, and, today,
# Nearest to into: from, in, through, by, with, agouti, dirty, on,
# Nearest to united: tabula, gland, vs, americas, gul, agp, wct, screenwriters,
# Nearest to would: can, will, should, may, could, must, to, sec,
# Nearest to has: had, have, was, is, tamarin, solicitation, waldemar, cl,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to th: six, nine, eight, seven, thibetanus, zero, five, sponsors,
# Nearest to while: aveiro, until, agouti, after, tamarin, dasyprocta, and, end,
# Nearest to be: have, been, was, by, are, almighty, is, were,
# Nearest to during: in, ssbn, through, from, at, when, stranded, agouti,
# Nearest to after: when, before, following, from, without, for, if, impulse,
# Nearest to when: after, if, although, but, before, in, was, through,
# Average loss at step  62000 :  4.7919331424236296
# Average loss at step  64000 :  4.789318866968155
# Average loss at step  66000 :  4.97206218445301
# Average loss at step  68000 :  4.911039072394371
# Average loss at step  70000 :  4.764898042201996
# Nearest to zero: six, eight, five, seven, four, nine, dasyprocta, three,
# Nearest to up: them, him, nonzero, microcebus, anacondas, modes, shifting, altenberg,
# Nearest to people: aveiro, gland, carbonic, reject, iota, callithrix, sartre, countries,
# Nearest to and: or, but, thibetanus, dasyprocta, tamarin, callithrix, microcebus, abet,
# Nearest to however: but, that, and, bebox, analogue, johanna, quadrilateral, thibetanus,
# Nearest to into: from, through, by, with, agouti, dirty, regained, pidgin,
# Nearest to united: tabula, gland, vs, americas, gul, agp, screenwriters, wct,
# Nearest to would: can, will, should, may, could, must, to, sec,
# Nearest to has: had, have, was, is, tamarin, solicitation, waldemar, microcebus,
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to th: six, eight, nine, seven, thibetanus, sponsors, solicitation, cider,
# Nearest to while: aveiro, until, after, however, agouti, and, in, dasyprocta,
# Nearest to be: been, have, by, is, are, were, almighty, was,
# Nearest to during: in, ssbn, through, from, mitral, at, when, agouti,
# Nearest to after: before, when, following, from, while, without, if, seventh,
# Nearest to when: after, if, although, mitral, but, before, was, through,
# Average loss at step  72000 :  4.807017092823982
# Average loss at step  74000 :  4.779230797022581
# Average loss at step  76000 :  4.852622120797634
# Average loss at step  78000 :  4.783856265664101
# Average loss at step  80000 :  4.821337711691856
# Nearest to zero: eight, six, five, seven, four, nine, dasyprocta, three,
# Nearest to up: them, him, nonzero, anacondas, shifting, out, hungary, dmitry,
# Nearest to people: aveiro, gland, carbonic, reject, iota, sartre, callithrix, microcebus,
# Nearest to and: or, but, thibetanus, dasyprocta, clodius, tamarin, callithrix, microcebus,
# Nearest to however: but, that, bebox, while, clodius, analogue, johanna, which,
# Nearest to into: from, through, by, in, agouti, with, within, dirty,
# Nearest to united: tabula, gland, vs, americas, gul, insistence, screenwriters, agp,
# Nearest to would: can, will, may, should, could, must, might, to,
# Nearest to has: had, have, is, was, waldemar, clodius, tamarin, solicitation,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to th: eight, six, nine, thibetanus, cider, solicitation, five, seven,
# Nearest to while: however, aveiro, agouti, after, dasyprocta, until, when, tamarin,
# Nearest to be: been, have, almighty, were, by, being, are, was,
# Nearest to during: in, through, ssbn, when, at, mitral, from, agouti,
# Nearest to after: before, when, following, from, without, while, if, seventh,
# Nearest to when: after, if, although, mitral, before, during, but, where,
# Average loss at step  82000 :  4.803129677891731
# Average loss at step  84000 :  4.805095793128014
# Average loss at step  86000 :  4.742085847496987
# Average loss at step  88000 :  4.702633556723595
# Average loss at step  90000 :  4.759896434783935
# Nearest to zero: five, eight, seven, six, nine, dasyprocta, four, three,
# Nearest to up: them, out, him, nonzero, anacondas, off, hungary, dmitry,
# Nearest to people: aveiro, gland, carbonic, callithrix, sartre, reject, iota, hcl,
# Nearest to and: or, but, thibetanus, dasyprocta, clodius, tamarin, callithrix, in,
# Nearest to however: but, that, and, which, bebox, while, clodius, today,
# Nearest to into: from, through, with, agouti, within, dirty, pidgin, by,
# Nearest to united: tabula, gland, americas, vs, insistence, screenwriters, oxycoccus, gul,
# Nearest to would: can, will, may, could, should, must, might, to,
# Nearest to has: had, have, was, is, clodius, tamarin, solicitation, waldemar,
# Nearest to five: four, seven, eight, six, three, nine, zero, two,
# Nearest to th: eight, seven, nine, six, five, thibetanus, zero, solicitation,
# Nearest to while: however, when, cuauht, but, after, dasyprocta, aveiro, agouti,
# Nearest to be: been, have, almighty, being, are, were, is, was,
# Nearest to during: in, through, when, ssbn, at, from, mitral, cuauht,
# Nearest to after: before, when, following, from, without, if, while, seventh,
# Nearest to when: if, after, although, before, mitral, where, during, but,
# Average loss at step  92000 :  4.708817445278168
# Average loss at step  94000 :  4.606937117218971
# Average loss at step  96000 :  4.719117977619171
# Average loss at step  98000 :  4.621636092782021
# Average loss at step  100000 :  4.693050562143326
# Nearest to zero: eight, five, six, four, seven, nine, dasyprocta, victoriae,
# Nearest to up: them, out, him, off, nonzero, anacondas, microcebus, sheikh,
# Nearest to people: aveiro, gland, sartre, callithrix, iota, carbonic, ecological, reject,
# Nearest to and: or, but, dasyprocta, thibetanus, tamarin, callithrix, clodius, microcebus,
# Nearest to however: but, that, bebox, which, and, clodius, while, analogue,
# Nearest to into: through, from, with, within, to, agouti, dirty, by,
# Nearest to united: tabula, gland, during, americas, screenwriters, vs, insistence, oxycoccus,
# Nearest to would: can, will, may, could, should, must, might, to,
# Nearest to has: had, have, was, is, clodius, tamarin, solicitation, maguey,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to th: eight, six, nine, seven, dativus, five, thibetanus, solicitation,
# Nearest to while: when, however, and, but, although, after, until, cuauht,
# Nearest to be: been, have, are, almighty, by, being, were, was,
# Nearest to during: in, through, when, ssbn, from, at, mitral, after,
# Nearest to after: before, when, following, without, from, while, during, seventh,
# Nearest to when: if, after, although, before, where, mitral, during, while,

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

  #%%
try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 200
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only,:])
  labels = [reverse_dictionary[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn, matplotlib, and scipy to visualize embeddings.")
